# %% [markdown]
# # 1. Exploratory data analysis

# %% [markdown]
# ## Dataset collection

# %%
from pathlib import Path
import os

current_dir = Path().resolve()
notebook_dir = Path(os.getcwd())

if current_dir != notebook_dir:
    raise RuntimeError(f"Please run from {notebook_dir}")

# %%
from src.paths import data_dir, tables_dir, figures_dir

# %%
data_dir
# Out:
# PosixPath('/wibicomfs/STBS/anastasia/epi_clean/data')

# %%
import sys, site
print(sys.executable)
# !{sys.executable} -m pip show mypkg
# Out:
# /home/ank24/miniconda3/envs/epi_env/bin/python
# WARNING: Package(s) not found: mypkg

# %%
import os

# dirs for the datasets
directory = "../data/somermeyer"
os.makedirs(directory, exist_ok=True)
# !mv ../data/zero_shot_substitutions_scores/*Somermeyer* ../data/somermeyer/

directory = "../data/tsuboyama"
os.makedirs(directory, exist_ok=True)
# !mv ../data/zero_shot_substitutions_scores/*Tsuboyama* ../data/tsuboyama/

# %% [markdown]
# ## Distribution of mutations

# %% [markdown]
# ## Distribution of GFP values

# %% [markdown]
# ## Distribution of Tsuboyama values
