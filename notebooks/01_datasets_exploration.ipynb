# %% [markdown]
# # 1. Exploratory data analysis

# %% [markdown]
# ## Dataset collection

# %%
# !python ../src/paths.py

# %%
from src.paths import data_dir, somermeyer_data_dir, tsuboyama_data_dir
import shutil
import pandas as pd

src_folder = data_dir / "zero_shot_substitutions_scores"

# Somermeyer
for file in src_folder.glob("*Somermeyer*"):
    shutil.move(file, somermeyer_data_dir / file.name)

# Tsuboyama
for file in src_folder.glob("*Tsuboyama*"):
    df = pd.read_csv(tsuboyama_data_dir / file)
    df["num_mutations"] = df["mutant"].apply(lambda x: len(x.split(":")))
    if df.num_mutations.nunique() > 1:
        shutil.move(file, tsuboyama_data_dir / file.name)
    else:
        print(f"File {file.name} has only single mutants. Skipping")
# Out:
# File ARGR_ECOLI_Tsuboyama_2023_1AOY.csv has only single mutants. Skipping
# File DN7A_SACS2_Tsuboyama_2023_1JIC.csv has only single mutants. Skipping
# File FKBP3_HUMAN_Tsuboyama_2023_2KFV.csv has only single mutants. Skipping
# File HCP_LAMBD_Tsuboyama_2023_2L6Q.csv has only single mutants. Skipping
# File ILF3_HUMAN_Tsuboyama_2023_2L33.csv has only single mutants. Skipping
# File OTU7A_HUMAN_Tsuboyama_2023_2L2D.csv has only single mutants. Skipping
# File PKN1_HUMAN_Tsuboyama_2023_1URF.csv has only single mutants. Skipping
# File RS15_GEOSE_Tsuboyama_2023_1A32.csv has only single mutants. Skipping
# File SBI_STAAM_Tsuboyama_2023_2JVG.csv has only single mutants. Skipping
# File SCIN_STAAR_Tsuboyama_2023_2QFF.csv has only single mutants. Skipping
# File SOX30_HUMAN_Tsuboyama_2023_7JJK.csv has only single mutants. Skipping
# File SQSTM_MOUSE_Tsuboyama_2023_2RRU.csv has only single mutants. Skipping
# File VG08_BPP22_Tsuboyama_2023_2GP8.csv has only single mutants. Skipping
# File VRPI_BPT7_Tsuboyama_2023_2WNM.csv has only single mutants. Skipping

# %% [markdown]
# ## GFP distributions

# %%
from src.utils import convert_name_to_gfp
from src.paths import somermeyer_data_dir
from pathlib import Path
import pandas as pd

for file in Path(somermeyer_data_dir).glob("*.csv"):
    df = pd.read_csv(file)
    name = file.stem
    name = convert_name_to_gfp(name)
    print("Number of genotypes in {}: {}".format(name, df.shape[0]))
# Out:
# Number of genotypes in cgreGFP: 24515
# Number of genotypes in ppluGFP: 31401
# Number of genotypes in amacGFP: 33510

# %%
from src.paths import somermeyer_data_dir, main_figures_dir
from src.plotting import mut_hist_somermeyer

mut_hist_somermeyer(
    somermeyer_data_dir,
    save_path=main_figures_dir / "2a_somermeyer_mutations_hist.png"
)

# %%
from src.paths import somermeyer_data_dir, main_figures_dir
from src.plotting import val_violin_somermeyer

val_violin_somermeyer(somermeyer_data_dir, save_path=main_figures_dir / "2b_somermeyer_values_hist.png")

# %% [markdown]
# ## Tsuboyama distributions

# %%
from src.utils import convert_name_to_gfp
from src.paths import tsuboyama_data_dir
from pathlib import Path
import pandas as pd

num_genotypes = []
for file in Path(tsuboyama_data_dir).glob("*.csv"):
    df = pd.read_csv(file)
    name = "_".join(file.stem.split("_")[:2])
    num_genotypes.append(df.shape[0])
print("Minimal number of genotypes in Tsuboyama datasets: {}".format(min(num_genotypes)))
print("Maximal number of genotypes in Tsuboyama datasets: {}".format(max(num_genotypes)))
print("Total number of genotypes in Tsuboyama datasets: {}".format(sum(num_genotypes)))
# Out:
# Minimal number of genotypes in Tsuboyama datasets: 802
# Maximal number of genotypes in Tsuboyama datasets: 5586
# Total number of genotypes in Tsuboyama datasets: 103055

# %%
from src.paths import tsuboyama_data_dir, main_figures_dir
from src.plotting import mut_hist_tsuboyama

mut_hist_tsuboyama(tsuboyama_data_dir, save_path=main_figures_dir / "2c_tsuboyama_mutations_hist.png")

# %%
from src.paths import tsuboyama_data_dir, main_figures_dir
from src.plotting import val_violin_tsuboyama

val_violin_tsuboyama(tsuboyama_data_dir, save_path=main_figures_dir / "2d_tsuboyama_values_hist.png")
